# %% [markdown]
# # Part 1: NYC 311 calls
#
# This notebook derives from a [demo by the makers of plot.ly](https://plot.ly/ipython-notebooks/big-data-analytics-with-pandas-and-sqlite/). We've adapted it to use [Bokeh (and HoloViews)](http://bokeh.pydata.org/en/latest/).
#
# You will start with a large database of complaints filed by residents of New York City since 2010 via 311 calls. The full dataset is available at the [NYC open data portal](https://nycopendata.socrata.com/data). At about 6 GB and 10 million complaints, you can infer that a) you might not want to read it all into memory at once, and b) NYC residents have a lot to complain about. (Maybe only conclusion "a" is valid.) The notebook then combines the use of `sqlite`, `pandas`, and `bokeh`.

# %% [markdown]
# > **Important note.** Due to a limitation in Vocareum's software stack, this notebook is set to use the Python 3.5 kernel (rather than a more up-to-date 3.6 or 3.7 kernel). If you are developing on your local machine and are using a different version of Python, you may need to adapt your solution before submitting to the autograder.

# %%
import sys
print("=== Python version info ===\n{}".format(sys.version))
# Out:
# === Python version info ===
# 3.5.2 (default, Nov 23 2017, 16:37:01)
# [GCC 5.4.0 20160609]

# %% [markdown]
# ## Module setup
#
# Before diving in, run the following cells to preload some functions you'll need later.

# %%
from IPython.display import display
import pandas as pd

# %% [markdown]
# We'll also need some functionality from earlier notebooks.

# %%
def canonicalize_tibble(X):
    var_names = sorted(X.columns)
    Y = X[var_names].copy()
    Y.sort_values(by=var_names, inplace=True)
    Y.reset_index(drop=True, inplace=True)
    return Y

def tibbles_are_equivalent (A, B):
    A_canonical = canonicalize_tibble(A)
    B_canonical = canonicalize_tibble(B)
    cmp = A_canonical.eq(B_canonical)
    return cmp.all().all()

def cast(df, key, value, join_how='outer'):
    """Casts the input data frame into a tibble,
    given the key column and value column.
    """
    assert type(df) is pd.DataFrame
    assert key in df.columns and value in df.columns
    assert join_how in ['outer', 'inner']
    
    fixed_vars = df.columns.difference([key, value])
    tibble = pd.DataFrame(columns=fixed_vars) # empty frame    
    new_vars = df[key].unique()
    for v in new_vars:
        df_v = df[df[key] == v]
        del df_v[key]
        df_v = df_v.rename(columns={value: v})
        tibble = tibble.merge(df_v,
                              on=list(fixed_vars),
                              how=join_how)    
    return tibble

# %% [markdown]
# Lastly, some of the test cells will need some auxiliary files, which the following code cell will check for and, if they are missing, download.

# %%
import requests
import os
import hashlib
import io

def download(file, url_suffix=None, checksum=None):
    if url_suffix is None:
        url_suffix = file
        
    if os.path.exists('.voc'):
        url = 'https://cse6040.gatech.edu/datasets/{}'.format(url_suffix)
    else:
        url = 'https://github.com/cse6040/labs-fa17/raw/master/{}'.format(url_suffix)
    if os.path.exists(file):
        print("[{}]\n==> '{}' is already available.".format(url, file))
    else:
        print("[{}] Downloading...".format(url))
        r = requests.get(url)
        with open(file, 'w', encoding=r.encoding) as f:
            f.write(r.text)
            
    if checksum is not None:
        with io.open(file, 'r', encoding='utf-8', errors='replace') as f:
            body = f.read()
            body_checksum = hashlib.md5(body.encode('utf-8')).hexdigest()
            assert body_checksum == checksum, \
                "Downloaded file '{}' has incorrect checksum: '{}' instead of '{}'".format(file, body_checksum, checksum)
            print("==> Checksum test passes: {}".format(checksum))
    
    print("==> '{}' is ready!\n".format(file))
    
auxfiles = {'df_complaints_by_city_soln.csv': '2a82e5856d5a267db9aafc26f16c3ae1',
            'df_complaints_by_hour_soln.csv': 'f06fcd917876d51ad52ddc13b2fee69e',
            'df_noisy_by_hour_soln.csv': '30f3fa7c753d4d3f4b3edfa1f6d05bcc',
            'df_plot_stacked_fraction_soln.csv': '2ca04a3eb24ccc37ddd0f8f5917fb27a'}

for filename, checksum in auxfiles.items():
    download(filename, url_suffix='{}/{}'.format('lab9-sql', filename), checksum=checksum)
    
print("(Auxiliary files appear to be ready.)")
# Out:
# [https://cse6040.gatech.edu/datasets/lab9-sql/df_plot_stacked_fraction_soln.csv]
# ==> 'df_plot_stacked_fraction_soln.csv' is already available.
# ==> Checksum test passes: 2ca04a3eb24ccc37ddd0f8f5917fb27a
# ==> 'df_plot_stacked_fraction_soln.csv' is ready!
#
# [https://cse6040.gatech.edu/datasets/lab9-sql/df_complaints_by_city_soln.csv]
# ==> 'df_complaints_by_city_soln.csv' is already available.
# ==> Checksum test passes: 2a82e5856d5a267db9aafc26f16c3ae1
# ==> 'df_complaints_by_city_soln.csv' is ready!
#
# [https://cse6040.gatech.edu/datasets/lab9-sql/df_complaints_by_hour_soln.csv]
# ==> 'df_complaints_by_hour_soln.csv' is already available.
# ==> Checksum test passes: f06fcd917876d51ad52ddc13b2fee69e
# ==> 'df_complaints_by_hour_soln.csv' is ready!
#
# [https://cse6040.gatech.edu/datasets/lab9-sql/df_noisy_by_hour_soln.csv]
# ==> 'df_noisy_by_hour_soln.csv' is already available.
# ==> Checksum test passes: 30f3fa7c753d4d3f4b3edfa1f6d05bcc
# ==> 'df_noisy_by_hour_soln.csv' is ready!
#
# (Auxiliary files appear to be ready.)

# %% [markdown]
# ## Viz setup
#
# This notebook includes some simple visualizations. This section just ensures you have the right software setup to follow along.

# %%
from bokeh.io import show, output_notebook
output_notebook()

from bokeh.plotting import figure

def make_barchart(df, labels, values, kwargs_figure={}):
    assert type(df) is pd.DataFrame
    assert type(labels) is str and type(values) is str
    p = figure(x_range=list(df[labels].unique()), **kwargs_figure)
    p.vbar(x=list(df[labels]), top=list(df[values]), width=0.9)
    return p
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3e00029d-694b-4b0f-8d02-b633f1e61936">Loading BokehJS ...</span>
#     </div>

# %%
def demo():
    from bokeh.plotting import figure, output_file, show
    from bokeh.models import ColumnDataSource
    data = [
        ['201720', 'cat1', 20],
        ['201720', 'cat2', 30],
        ['201720', 'cat3', 40],
        ['201721', 'cat1', 20],
        ['201721', 'cat2', 0],
        ['201721', 'cat3', 40],
        ['201722', 'cat1', 50],
        ['201722', 'cat2', 60],
        ['201722', 'cat3', 10],
    ]
    df = pd.DataFrame(data, columns=['week', 'category', 'count'])
    pt = df.pivot('week', 'category', 'count')
    pt.cumsum(axis=1)
    return df, pt

df_demo, pt_demo = demo()
pt_demo
# Out:
# category  cat1  cat2  cat3
# week
# 201720      20    30    40
# 201721      20     0    40
# 201722      50    60    10

# %%
def demo_stacked_bar(pt):
    from bokeh.models.ranges import FactorRange
    p = figure(title="count",
               x_axis_label='week', y_axis_label='category',
               x_range = FactorRange(factors=list(pt.index)),
               plot_height=300, plot_width=500)
    p.vbar(x=pt.index, bottom=0, top=pt.cat1, width=0.2, color='red', legend='cat1')
    p.vbar(x=pt.index, bottom=pt.cat1, top=pt.cat2, width=0.2, color='blue', legend='cat2')
    p.vbar(x=pt.index, bottom=pt.cat2, top=pt.cat3, width=0.2, color='green', legend='cat3')
    show(p)
    
demo_stacked_bar(pt_demo)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e6f837ec-9eba-4d06-bcec-1ac9c3f6b745"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e6f837ec-9eba-4d06-bcec-1ac9c3f6b745");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e6f837ec-9eba-4d06-bcec-1ac9c3f6b745");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e6f837ec-9eba-4d06-bcec-1ac9c3f6b745' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1ad405aa-ea9c-4796-b1a0-922507d225b3":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","bottom","top"],"data":{"bottom":[20,20,50],"top":[30,0,60],"x":["201720","201721","201722"]}},"id":"d251a168-aab6-4171-86a3-beb4e8c5bfb8","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":[20,20,50],"x":["201720","201721","201722"]}},"id":"4bcb9264-42cc-4219-81f3-c63a8d9da8a6","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"9788a8df-f4ba-4d81-8351-23bbc893188a","subtype":"Figure","type":"Plot"}},"id":"e348cebc-4242-45b3-9e2f-e43e727782b0","type":"WheelZoomTool"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"value":"green"},"line_color":{"value":"green"},"top":{"field":"top"},"width":{"value":0.2},"x":{"field":"x"}},"id":"1c42e422-6374-4af3-a2e0-731f8ffbbd5d","type":"VBar"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"top":{"field":"top"},"width":{"value":0.2},"x":{"field":"x"}},"id":"d9840d13-8ea0-4f9a-97f1-cce80c17051b","type":"VBar"},{"attributes":{},"id":"cd83dd5c-ba7a-4437-8b13-44ed595cc3a6","type":"BasicTicker"},{"attributes":{"callback":null},"id":"5c149444-aa7a-4269-9981-c698ace3e645","type":"DataRange1d"},{"attributes":{"axis_label":"category","formatter":{"id":"ff17a0ed-c882-44e0-b943-97cc050a2370","type":"BasicTickFormatter"},"plot":{"id":"9788a8df-f4ba-4d81-8351-23bbc893188a","subtype":"Figure","type":"Plot"},"ticker":{"id":"cd83dd5c-ba7a-4437-8b13-44ed595cc3a6","type":"BasicTicker"}},"id":"08cf15e4-44d2-4919-a130-59b0e960ae2b","type":"LinearAxis"},{"attributes":{"plot":{"id":"9788a8df-f4ba-4d81-8351-23bbc893188a","subtype":"Figure","type":"Plot"}},"id":"9a5bc94c-f543-40b1-a844-e1024bb546ad","type":"SaveTool"},{"attributes":{"label":{"value":"cat2"},"renderers":[{"id":"6666b6ea-dfdd-49c9-ba4c-0e25e734682c","type":"GlyphRenderer"}]},"id":"5eb5c03d-3bf5-462e-94ef-9d1f0f17be83","type":"LegendItem"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"top":{"field":"top"},"width":{"value":0.2},"x":{"field":"x"}},"id":"56d131b8-ace2-49db-8655-69cee8af8601","type":"VBar"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6516f096-0399-4ed7-abc9-29d72bda36c5","type":"PanTool"},{"id":"e348cebc-4242-45b3-9e2f-e43e727782b0","type":"WheelZoomTool"},{"id":"12cd7d50-2404-46d0-aefd-fc7470fa8e5d","type":"BoxZoomTool"},{"id":"9a5bc94c-f543-40b1-a844-e1024bb546ad","type":"SaveTool"},{"id":"ec745cd2-cf9d-4ebb-b8a9-55aae0bdaeed","type":"ResetTool"},{"id":"375fa1c0-2672-4cc9-8755-69693fb430b0","type":"HelpTool"}]},"id":"de1fb173-5887-4ca0-96e6-f01873896ef9","type":"Toolbar"},{"attributes":{"plot":{"id":"9788a8df-f4ba-4d81-8351-23bbc893188a","subtype":"Figure","type":"Plot"}},"id":"6516f096-0399-4ed7-abc9-29d72bda36c5","type":"PanTool"},{"attributes":{"plot":{"id":"9788a8df-f4ba-4d81-8351-23bbc893188a","subtype":"Figure","type":"Plot"},"ticker":{"id":"365acde7-06f3-42f6-a708-c05427292c4e","type":"CategoricalTicker"}},"id":"28ac46f9-567d-4611-a790-dd5608ec8a97","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"214970ea-e560-4f59-8340-ebed6a7a84d1","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"214970ea-e560-4f59-8340-ebed6a7a84d1","type":"BoxAnnotation"},"plot":{"id":"9788a8df-f4ba-4d81-8351-23bbc893188a","subtype":"Figure","type":"Plot"}},"id":"12cd7d50-2404-46d0-aefd-fc7470fa8e5d","type":"BoxZoomTool"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"wi ...

# %%
# Adapted from a mashup of:
# - https://bokeh.pydata.org/en/latest/docs/user_guide/categorical.html#userguide-categorical
# - https://groups.google.com/a/continuum.io/forum/#!topic/bokeh/x8j6EvJRty8
#
# This code is a hack to workaround an old installation of bokeh on Vocareum.

from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

def make_stacked_bar(df, x_var, cat_var, y_var, fillna=True,
                     x_labels=None, bar_labels=None,
                     kwargs_figure={}):
    from bokeh.core.properties import value
    from bokeh.models.ranges import FactorRange

    assert type(x_var) is str, "x-variable should be a string but isn't."
    assert type(cat_var) is str, "category variable should be a string but isn't."
    assert type(y_var) is str, "y-variable should be a string but isn't."
    
    pt = df.pivot(x_var, cat_var, y_var)
    if fillna:
        pt.fillna(0, inplace=True)
    pt = pt.cumsum(axis=1)
    bar_vars = pt.columns
    
    from bokeh.palettes import brewer
    assert len(bar_vars) in brewer['Dark2'], "Not enough colors."

    x = x_labels if x_labels is not None else FactorRange(factors=list(pt.index))
    legend = bar_labels if bar_labels is not None else list(bar_vars)
    colors = brewer['Dark2'][len(bar_vars)]
    source = ColumnDataSource(data=df)

    p = figure(x_range=x, **kwargs_figure)
    bot = 0
    for k, var in enumerate(bar_vars):
        p.vbar(x=pt.index, bottom=bot, top=pt[var], color=colors[k], legend=var, width=0.25)
        bot = pt[var]
    return p

# %%
# Build a Pandas data frame
names = ['Bob','Jessica','Mary','John','Mel']
births = [968, 155, 77, 578, 973]
name_birth_pairs = list(zip(names, births))
baby_names = pd.DataFrame(data=name_birth_pairs, columns=['Names', 'Births'])
display(baby_names)
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %% [markdown]
# > When you run `make_barchart()`, in the following code cell as well as subsequent ones, you can safely ignore any `FutureWarning` messages you see from Bokeh.

# %%
p = make_barchart(baby_names, 'Names', 'Births', kwargs_figure={'plot_width': 640, 'plot_height': 320})
show(p)
# Out:
# /usr/local/lib/python3.5/dist-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="649c9161-8638-4c90-8011-47cb0a43306b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("649c9161-8638-4c90-8011-47cb0a43306b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("649c9161-8638-4c90-8011-47cb0a43306b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '649c9161-8638-4c90-8011-47cb0a43306b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1d22d6af-9b80-48db-ae0d-02fd8aafd683":{"roots":{"references":[{"attributes":{},"id":"eed539b8-22f4-454e-83f7-4f4d76b25b4d","type":"BasicTickFormatter"},{"attributes":{},"id":"b6c9e92c-98b3-437c-bdcc-7f5991dfe9ad","type":"BasicTicker"},{"attributes":{"formatter":{"id":"12a62709-c8bb-47cb-b864-57823fedb404","type":"CategoricalTickFormatter"},"plot":{"id":"0f92eeb0-fa6b-478a-8868-bc626d84b42f","subtype":"Figure","type":"Plot"},"ticker":{"id":"607b0a8d-7dde-4732-9fb4-7a5537de7fb7","type":"CategoricalTicker"}},"id":"962f18af-0751-49a7-8842-47f573f43c3d","type":"CategoricalAxis"},{"attributes":{"overlay":{"id":"4407dd97-5aed-43bb-8fe4-e374677c7a3f","type":"BoxAnnotation"},"plot":{"id":"0f92eeb0-fa6b-478a-8868-bc626d84b42f","subtype":"Figure","type":"Plot"}},"id":"1d50b50b-fc76-464c-8444-46ee04160a08","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"0f92eeb0-fa6b-478a-8868-bc626d84b42f","subtype":"Figure","type":"Plot"},"ticker":{"id":"607b0a8d-7dde-4732-9fb4-7a5537de7fb7","type":"CategoricalTicker"}},"id":"9abbe347-a1ab-48be-b342-f1652df77d06","type":"Grid"},{"attributes":{"plot":{"id":"0f92eeb0-fa6b-478a-8868-bc626d84b42f","subtype":"Figure","type":"Plot"}},"id":"b44d0c5b-2b55-4953-8425-9cb686a841f8","type":"PanTool"},{"attributes":{},"id":"12a62709-c8bb-47cb-b864-57823fedb404","type":"CategoricalTickFormatter"},{"attributes":{"below":[{"id":"962f18af-0751-49a7-8842-47f573f43c3d","type":"CategoricalAxis"}],"left":[{"id":"68bee867-48c0-4361-affd-1978c79e92cf","type":"LinearAxis"}],"plot_height":320,"plot_width":640,"renderers":[{"id":"962f18af-0751-49a7-8842-47f573f43c3d","type":"CategoricalAxis"},{"id":"9abbe347-a1ab-48be-b342-f1652df77d06","type":"Grid"},{"id":"68bee867-48c0-4361-affd-1978c79e92cf","type":"LinearAxis"},{"id":"ca8ef4bd-a403-4ecd-b0a5-7b6c9dab9391","type":"Grid"},{"id":"4407dd97-5aed-43bb-8fe4-e374677c7a3f","type":"BoxAnnotation"},{"id":"30d9167e-9b04-45a7-96cf-3798f4f35aaf","type":"GlyphRenderer"}],"title":{"id":"f02acf1a-fae8-4457-99de-a0c1ed90a98b","type":"Title"},"tool_events":{"id":"cac50167-6684-46d4-b867-fb930cc4ffe7","type":"ToolEvents"},"toolbar":{"id":"6f18c757-2cc3-4bda-8c14-e8dc75fac30c","type":"Toolbar"},"x_range":{"id":"e9c6b2d1-4f81-49a8-8b21-0ad8dfcdb6aa","type":"FactorRange"},"x_scale":{"id":"ef001430-1fd2-44d3-9863-46863349018c","type":"CategoricalScale"},"y_range":{"id":"78f9fafd-d6f0-403b-9cbd-2fad33396508","type":"DataRange1d"},"y_scale":{"id":"307b54ec-8626-44fb-bdde-f64d682436c2","type":"LinearScale"}},"id":"0f92eeb0-fa6b-478a-8868-bc626d84b42f","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b44d0c5b-2b55-4953-8425-9cb686a841f8","type":"PanTool"},{"id":"f9af0add-1067-4abb-afaa-0ce14fcdfbf3","type":"WheelZoomTool"},{"id":"1d50b50b-fc76-464c-8444-46ee04160a08","type":"BoxZoomTool"},{"id":"b85e180e-ad0a-4b22-a5ae-59730367c8d1","type":"SaveTool"},{"id":"24efd027-eb74-4ceb-99e7-f6cdc1d8a8bc","type":"ResetTool"},{"id":"73394816-cf99-4f4e-9a41-3f884e075615","type":"HelpTool"}]},"id":"6f18c757-2cc3-4bda-8c14-e8dc75fac30c","type":"Toolbar"},{"attributes":{"callback":null},"id":"78f9fafd-d6f0-403b-9cbd-2fad33396508","type":"DataRange1d"},{"attributes":{"callback":null,"factors":["Bob","Jessica","Mary","John","Mel"]},"id":"e9c6b2d1-4f81-49a8-8b21-0ad8dfcdb6aa","type":"FactorRange"},{"attributes":{"plot":{"id":"0f92eeb0-fa6b-478a-8868-bc626d84b42f","subtype":"Figure","type":"Plot"}},"id":"24efd027-eb74-4ceb-99e7-f6cdc1d8a8bc","type":"ResetTool"},{"attributes":{"plot":{"id":"0f92eeb0-fa6b-478a-8868-bc626d84b42f","subtype":"Figure","type":"Plot"}},"id":"73394816-cf99-4f4e-9a41-3f884e075615","type":"HelpTool"},{"attributes":{},"id":"ef001430-1fd2-44d3-9863-46863349018c","type":"CategoricalScale"},{"attributes":{},"id":"307b54ec-8626-44fb-bdde-f64d682436c2","type":"LinearScale"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"field": ...

# %% [markdown]
# ## Data setup
#
# You'll also need the NYC 311 calls dataset. What we've provided is actually a small subset (about 250+ MB) of the full data as of 2015.

# %%
import requests
import os
import hashlib
import io

def on_vocareum():
    return os.path.exists('.voc')

if on_vocareum():
    DB_FILENAME = "../resource/asnlib/publicdata/NYC-311-2M.db"
else:
    DB_FILENAME = 'NYC-311-2M.db'
    if not os.path.exists(DB_FILENAME):
        url = 'https://onedrive.live.com/download?cid=FD520DDC6BE92730&resid=FD520DDC6BE92730%21616&authkey=AEeP_4E1uh-vyDE'
        print("Downloading: {} ...".format(url))
        r = requests.get(url)
        with open(DB_FILENAME, 'w', encoding=r.encoding) as f:
            f.write(r.text)

DB_CHECKSUM = 'f48eba2fb06e8ece7479461ea8c6dee9'
with io.open(DB_FILENAME, 'rb') as f:
    body = f.read()
    body_checksum = hashlib.md5(body).hexdigest()
    assert body_checksum == DB_CHECKSUM, \
        "Database file '{}' has an incorrect checksum: '{}' instead of '{}'".format(DB_FILENAME,
                                                                                    body_checksum,
                                                                                    DB_CHECKSUM)
    
print("'{}' is ready!".format(DB_FILENAME))  
print("\n(All data appears to be ready.)")
# Out:
# '../resource/asnlib/publicdata/NYC-311-2M.db' is ready!
#
# (All data appears to be ready.)

# %% [markdown]
# **Connecting.** Let's open up a connection to this dataset.

# %%
# Connect
import sqlite3 as db
disk_engine = db.connect(DB_FILENAME)

# %% [markdown]
# **Preview the data.** This sample database has just a single table, named `data`. Let's query it and see how long it takes to read. To carry out the query, we will use the SQL reader built into `pandas`.

# %%
import time

print ("Reading ...")
start_time = time.time ()

# Perform SQL query through the disk_engine connection.
# The return value is a pandas data frame.
df = pd.read_sql_query ('SELECT * FROM data', disk_engine)

elapsed_time = time.time () - start_time
print ("==> Took %g seconds." % elapsed_time)

# Dump the first few rows
df.head()
# Out:
# Reading ...
# ==> Took 6.28739 seconds.
#    index                 CreatedDate                  ClosedDate Agency  \
# 0      1  2015-09-15 02:14:04.000000                        None   NYPD
# 1      2  2015-09-15 02:12:49.000000                        None   NYPD
# 2      3  2015-09-15 02:11:19.000000                        None   NYPD
# 3      4  2015-09-15 02:09:46.000000                        None   NYPD
# 4      5  2015-09-15 02:08:01.000000  2015-09-15 02:08:18.000000    DHS
#
#                 ComplaintType       Descriptor      City
# 0             Illegal Parking  Blocked Hydrant      None
# 1     Noise - Street/Sidewalk     Loud Talking  NEW YORK
# 2     Noise - Street/Sidewalk     Loud Talking  NEW YORK
# 3          Noise - Commercial     Loud Talking     BRONX
# 4  Homeless Person Assistance      Status Call  NEW YORK

# %% [markdown]
# **Partial queries: `LIMIT` clause.** The preceding command was overkill for what we wanted, which was just to preview the table. Instead, we could have used the `LIMIT` option to ask for just a few results.

# %%
query = '''
  SELECT *
    FROM data
    LIMIT 5
'''
start_time = time.time ()
df = pd.read_sql_query (query, disk_engine)
elapsed_time = time.time () - start_time
print ("==> LIMIT version took %g seconds." % elapsed_time)

df
# Out:
# ==> LIMIT version took 0.00657558 seconds.
#    index                 CreatedDate                  ClosedDate Agency  \
# 0      1  2015-09-15 02:14:04.000000                        None   NYPD
# 1      2  2015-09-15 02:12:49.000000                        None   NYPD
# 2      3  2015-09-15 02:11:19.000000                        None   NYPD
# 3      4  2015-09-15 02:09:46.000000                        None   NYPD
# 4      5  2015-09-15 02:08:01.000000  2015-09-15 02:08:18.000000    DHS
#
#                 ComplaintType       Descriptor      City
# 0             Illegal Parking  Blocked Hydrant      None
# 1     Noise - Street/Sidewalk     Loud Talking  NEW YORK
# 2     Noise - Street/Sidewalk     Loud Talking  NEW YORK
# 3          Noise - Commercial     Loud Talking     BRONX
# 4  Homeless Person Assistance      Status Call  NEW YORK

# %% [markdown]
# **Grouping Information: GROUP BY operator.** The GROUP BY operator lets you group information using a particular column or multiple columns of the table. The output generated is more of a pivot table.

# %%
query = '''
  SELECT ComplaintType, Descriptor, Agency
    FROM data
    GROUP BY ComplaintType
    ORDER BY ComplaintType
    LIMIT 10
'''

df = pd.read_sql_query(query, disk_engine)
df.head()
# Out:
#     ComplaintType                             Descriptor Agency
# 0          AGENCY              HOUSING QUALITY STANDARDS    HPD
# 1       APPLIANCE                           REFRIGERATOR    HPD
# 2  Adopt-A-Basket                     10A Adopt-A-Basket   DSNY
# 3   Agency Issues                 Call Center Compliment  3-1-1
# 4     Air Quality  Air: Odor/Fumes, Vehicle Idling (AD3)    DEP

# %%
query = '''
  SELECT ComplaintType, Descriptor, Agency
    FROM data
    ORDER BY ComplaintType
    LIMIT 10
'''

df = pd.read_sql_query(query, disk_engine)
df.head()
# Out:
#   ComplaintType                 Descriptor Agency
# 0        AGENCY  HOUSING QUALITY STANDARDS    HPD
# 1        AGENCY  HOUSING QUALITY STANDARDS    HPD
# 2     APPLIANCE         ELECTRIC/GAS RANGE    HPD
# 3     APPLIANCE               REFRIGERATOR    HPD
# 4     APPLIANCE         ELECTRIC/GAS RANGE    HPD

# %% [markdown]
# **Set membership: `IN` operator.** Another common idiom is to ask for rows whose attributes fall within a set, for which you can use the `IN` operator.

# %%
query = '''
  SELECT ComplaintType, Descriptor, Agency
    FROM data
    WHERE Agency IN ("NYPD", "DOB")
    LIMIT 10
'''

df = pd.read_sql_query (query, disk_engine)
df.head ()
# Out:
#              ComplaintType       Descriptor Agency
# 0          Illegal Parking  Blocked Hydrant   NYPD
# 1  Noise - Street/Sidewalk     Loud Talking   NYPD
# 2  Noise - Street/Sidewalk     Loud Talking   NYPD
# 3       Noise - Commercial     Loud Talking   NYPD
# 4         Blocked Driveway   Partial Access   NYPD

# %% [markdown]
# **Finding unique values: `DISTINCT` qualifier.** Yet another common idiom is to ask for the unique values of some attribute, for which you can use the `DISTINCT` qualifier.

# %%
query = 'SELECT DISTINCT City FROM data'
df = pd.read_sql_query(query, disk_engine)

print("Found {} unique cities. The first few are:".format(len(df)))
df.head()
# Out:
# Found 547 unique cities. The first few are:
#             City
# 0           None
# 1       NEW YORK
# 2          BRONX
# 3  STATEN ISLAND
# 4       ELMHURST

# %% [markdown]
# **Renaming columns: `AS` operator.** Sometimes you might want to rename a result column. For instance, the following query counts the number of complaints by "Agency," using the `COUNT(*)` function and `GROUP BY` clause, which we discussed in an earlier lab. If you wish to refer to the counts column of the resulting data frame, you can give it a more "friendly" name using the `AS` operator.

# %%
query = '''
  SELECT Agency, COUNT(*) AS NumComplaints
    FROM data
    GROUP BY Agency
'''
df = pd.read_sql_query(query, disk_engine)
df.head()
# Out:
#   Agency  NumComplaints
# 0  3-1-1           1289
# 1    ACS              3
# 2    AJC              6
# 3    CAU              1
# 4   CCRB              1

# %% [markdown]
# **Ordering results: `ORDER` clause.** You can also order the results. For instance, suppose we want to execute the previous query by number of complaints.

# %%
query = '''
  SELECT Agency, COUNT(*) AS NumComplaints
    FROM data
    GROUP BY Agency
    ORDER BY NumComplaints
'''
df = pd.read_sql_query(query, disk_engine)
df.tail()
# Out:
#    Agency  NumComplaints
# 45   DSNY         152004
# 46    DEP         181121
# 47    DOT         322969
# 48   NYPD         340694
# 49    HPD         640096

# %% [markdown]
# Note that the above example prints the bottom (tail) of the data frame. You could have also asked for the query results in reverse (descending) order, by prefixing the `ORDER BY` attribute with a `-` (minus) symbol. Alternatively, you can use `DESC` to achieve the same result.

# %%
query = '''
  SELECT Agency, COUNT(*) AS NumComplaints
    FROM data
    GROUP BY Agency
    ORDER BY -NumComplaints 
'''

# Alternative: query =
'''
SELECT Agency, COUNT(*) AS NumComplaints 
    FROM data 
    GROUP BY Agency
    ORDER BY NumComplaints DESC 
'''

df = pd.read_sql_query(query, disk_engine)
df.head()
# Out:
#   Agency  NumComplaints
# 0    HPD         640096
# 1   NYPD         340694
# 2    DOT         322969
# 3    DEP         181121
# 4   DSNY         152004

# %% [markdown]
# And of course we can plot all of this data!
#
# **Exercise 0** (ungraded). Run the following code cell, which will create an interactive bar chart from the data in the previous query.

# %%
p = make_barchart(df[:20], 'Agency', 'NumComplaints',
                  {'title': 'Top 20 agencies by number of complaints',
                   'plot_width': 800, 'plot_height': 320})
p.xaxis.major_label_orientation = 0.66
show(p)
# Out:
# /usr/local/lib/python3.5/dist-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c41b06f6-1ae1-406d-b100-ef827b5e57eb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c41b06f6-1ae1-406d-b100-ef827b5e57eb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c41b06f6-1ae1-406d-b100-ef827b5e57eb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c41b06f6-1ae1-406d-b100-ef827b5e57eb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"31d182cb-988f-4a01-b964-db6dba1bc80a":{"roots":{"references":[{"attributes":{},"id":"13a8ce2a-90a2-4c8b-b0d6-ce04a00e816a","type":"CategoricalScale"},{"attributes":{"dimension":1,"plot":{"id":"ed58328d-3fdc-4da2-9b78-a0cc3b4e470f","subtype":"Figure","type":"Plot"},"ticker":{"id":"bc546551-e98c-479e-a836-64692d71d692","type":"BasicTicker"}},"id":"e950e513-3402-4305-b144-a9429f483289","type":"Grid"},{"attributes":{},"id":"6868b787-0fdd-430e-8bf1-e1fd242afaaf","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.9},"x":{"field":"x"}},"id":"426c4f9e-8fef-4e9c-baca-4f16c5faaecb","type":"VBar"},{"attributes":{},"id":"921cab44-ee11-4dd1-9884-a243262a5a93","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":[640096,340694,322969,181121,152004,87532,73499,57808,41915,27482,24214,20731,12282,7057,4559,1715,1679,1289,488,406],"x":["HPD","NYPD","DOT","DEP","DSNY","DOB","DPR","DOHMH","DOF","HRA","TLC","DCA","CHALL","FDNY","DHS","EDC","DOE","3-1-1","DOITT","DFTA"]}},"id":"79f5ab5e-66a7-4bea-9555-7d771c3cbeb8","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"79f5ab5e-66a7-4bea-9555-7d771c3cbeb8","type":"ColumnDataSource"},"glyph":{"id":"fbaeaa5b-4ae4-4170-ab53-28e489c6e695","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"426c4f9e-8fef-4e9c-baca-4f16c5faaecb","type":"VBar"},"selection_glyph":null},"id":"b8a96e3b-151d-4b35-988b-8731c9510200","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e28d8196-c7d8-4821-8443-4d8fa9ca35e0","type":"PanTool"},{"id":"eb27050b-6baf-437f-85c5-0ca5aac7ccd1","type":"WheelZoomTool"},{"id":"75bec65e-4d7e-4f59-90b3-2c3e9e46683d","type":"BoxZoomTool"},{"id":"99010586-ff2c-4ca5-9604-12465c19ecd7","type":"SaveTool"},{"id":"028a7e4d-5fcc-41c8-9e13-0aee1febf2a9","type":"ResetTool"},{"id":"fbbefeb5-a1bf-4b83-869b-7a281d8e2b5b","type":"HelpTool"}]},"id":"b1ec0cc7-05dc-4dee-8f8c-7344603a6399","type":"Toolbar"},{"attributes":{"plot":{"id":"ed58328d-3fdc-4da2-9b78-a0cc3b4e470f","subtype":"Figure","type":"Plot"}},"id":"e28d8196-c7d8-4821-8443-4d8fa9ca35e0","type":"PanTool"},{"attributes":{},"id":"377f6e7d-9ed7-41ee-b717-f8a178267a73","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"ed58328d-3fdc-4da2-9b78-a0cc3b4e470f","subtype":"Figure","type":"Plot"}},"id":"eb27050b-6baf-437f-85c5-0ca5aac7ccd1","type":"WheelZoomTool"},{"attributes":{},"id":"45d5981c-eb1e-44a1-819c-33f5fcead4dd","type":"LinearScale"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d99faf8a-9057-427f-9935-01fadcb8d3ee","type":"BoxAnnotation"},{"attributes":{},"id":"314753a7-f172-4b7b-963d-6b583e20a178","type":"CategoricalTickFormatter"},{"attributes":{"plot":null,"text":"Top 20 agencies by number of complaints"},"id":"892397a5-bf50-4f14-9679-726f9e1f6acc","type":"Title"},{"attributes":{"below":[{"id":"8c7a9efe-dd37-469e-bb30-13c7adffc5f5","type":"CategoricalAxis"}],"left":[{"id":"e8cdc6c5-2f9e-4fee-a624-777244dd000a","type":"LinearAxis"}],"plot_height":320,"plot_width":800,"renderers":[{"id":"8c7a9efe-dd37-469e-bb30-13c7adffc5f5","type":"CategoricalAxis"},{"id":"eebe6b92-f7e2-4827-aac3-51961c7d559a","type":"Grid"},{"id":"e8cdc6c5-2f9e-4fee-a624-777244dd000a","type":"LinearAxis"},{"id":"e950e513-3402-4305-b144-a9429f483289","type":"Grid"},{"id":"d99faf8a-9057-427f-9935-01fadcb8d3ee","type":"BoxAnnotation"},{"id":"b8a96e3b-151d-4b35-988b-8731c9510200","type":"GlyphRenderer"}],"title":{"id":"892397a5-bf50-4f14-9679-726f9e1f6ac ...

# %% [markdown]
# **Exercise 1** (2 points). Create a string, `query`, containing an SQL query that will return the number of complaints by type. The columns should be named `type` and `freq`, and the results should be sorted in descending order by `freq`.
#
# > What is the most common type of complaint? What, if anything, does it tell you about NYC?

# %%
del query

query = '''
    SELECT ComplaintType as type, COUNT(*) AS freq
    FROM data
    GROUP BY ComplaintType
    ORDER BY freq DESC
'''

# Runs your `query`:
df_complaint_freq = pd.read_sql_query(query, disk_engine)
df_complaint_freq.head()
# Out:
#                      type    freq
# 0          HEAT/HOT WATER  241430
# 1        Street Condition  124347
# 2  Street Light Condition   98577
# 3        Blocked Driveway   95080
# 4         Illegal Parking   83961

# %%
# Test cell: `complaints_test`

print("Top 10 complaints:")
display(df_complaint_freq.head(10))

assert set(df_complaint_freq.columns) == {'type', 'freq'}, "Output columns should be named 'type' and 'freq', not {}".format(set(df_complaint_freq.columns))

soln = ['HEAT/HOT WATER', 'Street Condition', 'Street Light Condition', 'Blocked Driveway', 'Illegal Parking', 'UNSANITARY CONDITION', 'PAINT/PLASTER', 'Water System', 'PLUMBING', 'Noise', 'Noise - Street/Sidewalk', 'Traffic Signal Condition', 'Noise - Commercial', 'DOOR/WINDOW', 'WATER LEAK', 'Dirty Conditions', 'Sewer', 'Sanitation Condition', 'DOF Literature Request', 'ELECTRIC', 'Rodent', 'FLOORING/STAIRS', 'General Construction/Plumbing', 'Building/Use', 'Broken Muni Meter', 'GENERAL', 'Missed Collection (All Materials)', 'Benefit Card Replacement', 'Derelict Vehicle', 'Noise - Vehicle', 'Damaged Tree', 'Consumer Complaint', 'Derelict Vehicles', 'Taxi Complaint', 'Overgrown Tree/Branches', 'Graffiti', 'Snow', 'Opinion for the Mayor', 'APPLIANCE', 'Maintenance or Facility', 'Animal Abuse', 'Dead Tree', 'HPD Literature Request', 'Root/Sewer/Sidewalk Condition', 'SAFETY', 'Elevator', 'Food Establishment', 'SCRIE', 'Air Quality', 'Agency Issues', 'Construction', 'Highway Condition', 'Other Enforcement', 'Water Conservation', 'Sidewalk Condition', 'Indoor Air Quality', 'Street Sign - Damaged', 'Traffic', 'Plumbing', 'Fire Safety Director - F58', 'Homeless Person Assistance', 'Homeless Encampment', 'Special Enforcement', 'Street Sign - Missing', 'Noise - Park', 'Vending', 'For Hire Vehicle Complaint', 'Food Poisoning', 'Special Projects Inspection Team (SPIT)', 'Hazardous Materials', 'Electrical', 'DOT Literature Request', 'Litter Basket / Request', 'Taxi Report', 'Illegal Tree Damage', 'DOF Property - Reduction Issue', 'Unsanitary Animal Pvt Property', 'Asbestos', 'Lead', 'Vacant Lot', 'DCA / DOH New License Application Request', 'Street Sign - Dangling', 'Smoking', 'Violation of Park Rules', 'OUTSIDE BUILDING', 'Animal in a Park', 'Noise - Helicopter', 'School Maintenance', 'DPR Internal', 'Boilers', 'Industrial Waste', 'Sweeping/Missed', 'Overflowing Litter Baskets', 'Non-Residential Heat', 'Curb Condition', 'Drinking', 'Standing Water', 'Indoor Sewage', 'Water Quality', 'EAP Inspection - F59', 'Derelict Bicycle', 'Noise - House of Worship', 'DCA Literature Request', 'Recycling Enforcement', 'ELEVATOR', 'DOF Parking - Tax Exemption', 'Broken Parking Meter', 'Request for Information', 'Taxi Compliment', 'Unleashed Dog', 'Urinating in Public', 'Unsanitary Pigeon Condition', 'Investigations and Discipline (IAD)', 'Bridge Condition', 'Ferry Inquiry', 'Bike/Roller/Skate Chronic', 'Public Payphone Complaint', 'Vector', 'BEST/Site Safety', 'Sweeping/Inadequate', 'Disorderly Youth', 'Found Property', 'Mold', 'Senior Center Complaint', 'Fire Alarm - Reinspection', 'For Hire Vehicle Report', 'City Vehicle Placard Complaint', 'Cranes and Derricks', 'Ferry Complaint', 'Illegal Animal Kept as Pet', 'Posting Advertisement', 'Harboring Bees/Wasps', 'Panhandling', 'Scaffold Safety', 'OEM Literature Request', 'Plant', 'Bus Stop Shelter Placement', 'Collection Truck Noise', 'Beach/Pool/Sauna Complaint', 'Complaint', 'Compliment', 'Illegal Fireworks', 'Fire Alarm - Modification', 'DEP Literature Request', 'Drinking Water', 'Fire Alarm - New System', 'Poison Ivy', 'Bike Rack Condition', 'Emergency Response Team (ERT)', 'Municipal Parking Facility', 'Tattooing', 'Unsanitary Animal Facility', 'Animal Facility - No Permit', 'Miscellaneous Categories', 'Misc. Comments', 'Literature Request', 'Special Natural Area District (SNAD)', 'Highway Sign - Damaged', 'Public Toilet', 'Adopt-A-Basket', 'Ferry Permit', 'Invitation', 'Window Guard', 'Parking Card', 'Illegal Animal Sold', 'Stalled Sites', 'Open Flame Permit', 'Overflowing Recycling Baskets', 'Highway Sign - Missing', 'Public Assembly', 'DPR Literature Request', 'Fire Alarm - Addition', 'Lifeguard', 'Transportation Provider Complaint', 'DFTA Literature Request', 'Bottled Water', 'Highway Sign - Dangling', 'DHS Income Savings Requirement', 'Legal Services Provider Complaint', 'Foam Ban Enforcement', 'Tunnel Condition', 'Calorie Labeling', 'Fire Alarm - Replacement', 'X-Ray Machine/Equipment', 'Sprinkler - Mechanical', 'Hazmat Storage/Use', 'Tanning', 'Radioactive Material', 'Rangehood', 'SRDE', 'Squeegee', 'Building Condition', 'SG-98', 'Standpipe - Mechanical', 'AGENCY', 'Forensic Engineering', 'Public Assembly - Temporary', 'VACANT APARTMENT', 'Laboratory', 'SG-99']
assert all(soln == df_complaint_freq['type'])

print("\n(Passed.)")
# Out:
# Top 10 complaints:
#                      type    freq
# 0          HEAT/HOT WATER  241430
# 1        Street Condition  124347
# 2  Street Light Condition   98577
# 3        Blocked Driveway   95080
# 4         Illegal Parking   83961
# 5    UNSANITARY CONDITION   81394
# 6           PAINT/PLASTER   69929
# 7            Water System   69209
# 8                PLUMBING   55445
# 9                   Noise   54165
# (Passed.)

# %% [markdown]
# Let's also visualize the result, as a bar chart showing complaint types on the x-axis and the number of complaints on the y-axis.

# %%
p = make_barchart(df_complaint_freq[:25], 'type', 'freq',
                  {'title': 'Top 25 complaints by type',
                   'plot_width': 800, 'plot_height': 320})
p.xaxis.major_label_orientation = 0.66
show(p)
# Out:
# /usr/local/lib/python3.5/dist-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="79c173cb-ae7c-43fb-9aa7-d36b6fa3bca6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("79c173cb-ae7c-43fb-9aa7-d36b6fa3bca6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("79c173cb-ae7c-43fb-9aa7-d36b6fa3bca6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '79c173cb-ae7c-43fb-9aa7-d36b6fa3bca6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5974090d-fcef-4c30-8a3a-ea8e6bf065c4":{"roots":{"references":[{"attributes":{},"id":"fc0288bb-e192-4887-9024-93d6c1a78386","type":"ToolEvents"},{"attributes":{"formatter":{"id":"b170a271-0576-4ca6-a6bd-db24a00bf79b","type":"CategoricalTickFormatter"},"major_label_orientation":0.66,"plot":{"id":"be20271d-a3d8-4edb-9c31-b99f71aeda18","subtype":"Figure","type":"Plot"},"ticker":{"id":"abfab6c4-7952-4479-8317-ce1034d7d1be","type":"CategoricalTicker"}},"id":"63376593-a061-428a-9fcd-f4922750c843","type":"CategoricalAxis"},{"attributes":{"plot":null,"text":"Top 25 complaints by type"},"id":"95975ff2-920b-4be2-9b34-08338c8a748f","type":"Title"},{"attributes":{"callback":null,"factors":["HEAT/HOT WATER","Street Condition","Street Light Condition","Blocked Driveway","Illegal Parking","UNSANITARY CONDITION","PAINT/PLASTER","Water System","PLUMBING","Noise","Noise - Street/Sidewalk","Traffic Signal Condition","Noise - Commercial","DOOR/WINDOW","WATER LEAK","Dirty Conditions","Sewer","Sanitation Condition","DOF Literature Request","ELECTRIC","Rodent","FLOORING/STAIRS","General Construction/Plumbing","Building/Use","Broken Muni Meter"]},"id":"45fba80d-d34c-473a-811c-9c27a70b74b9","type":"FactorRange"},{"attributes":{"plot":{"id":"be20271d-a3d8-4edb-9c31-b99f71aeda18","subtype":"Figure","type":"Plot"}},"id":"d6bf888f-9e00-450c-a759-b8a004f5b29e","type":"SaveTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.9},"x":{"field":"x"}},"id":"3cf8421a-8a64-4bcd-b0d8-1ad8963512ca","type":"VBar"},{"attributes":{"plot":{"id":"be20271d-a3d8-4edb-9c31-b99f71aeda18","subtype":"Figure","type":"Plot"}},"id":"88255157-9f42-4986-9dd9-a9f469159370","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"be20271d-a3d8-4edb-9c31-b99f71aeda18","subtype":"Figure","type":"Plot"},"ticker":{"id":"2c0921a3-98a3-4a1a-9ce2-09bee76aacea","type":"BasicTicker"}},"id":"7f992983-892b-4233-ba14-22abf107aad0","type":"Grid"},{"attributes":{"plot":{"id":"be20271d-a3d8-4edb-9c31-b99f71aeda18","subtype":"Figure","type":"Plot"}},"id":"030ca3c3-53de-4838-8f73-a3adf7f222db","type":"HelpTool"},{"attributes":{"plot":{"id":"be20271d-a3d8-4edb-9c31-b99f71aeda18","subtype":"Figure","type":"Plot"},"ticker":{"id":"abfab6c4-7952-4479-8317-ce1034d7d1be","type":"CategoricalTicker"}},"id":"1e3bb80e-f07d-4420-8003-ce1fe33a89fe","type":"Grid"},{"attributes":{},"id":"42c106a5-bc6a-4830-aac6-2c63cf61556b","type":"CategoricalScale"},{"attributes":{"data_source":{"id":"645177e0-31df-4062-9e05-8e45350b9419","type":"ColumnDataSource"},"glyph":{"id":"3cf8421a-8a64-4bcd-b0d8-1ad8963512ca","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6f550b4c-23c0-4658-971f-4cf0d59ca024","type":"VBar"},"selection_glyph":null},"id":"2874765c-0c43-485b-9e9c-a3de04eacf96","type":"GlyphRenderer"},{"attributes":{},"id":"dfeb92ef-f16a-4094-823d-446cbbcdf38e","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"dfeb92ef-f16a-4094-823d-446cbbcdf38e","type":"BasicTickFormatter"},"plot":{"id":"be20271d-a3d8-4edb-9c31-b99f71aeda18","subtype":"Figure","type":"Plot"},"ticker":{"id":"2c0921a3-98a3-4a1a-9ce2-09bee76aacea","type":"BasicTicker"}},"id":"017fb2f9-d461-4d06-896d-0eb289cea091","type":"LinearAxis"},{"attributes":{"overlay":{"id":"0b7e2c53-cf87-4343-86aa-a9b3852cc8a3","type":"BoxAnnotation"},"plot":{"id":"be20271d-a3d8-4edb-9c31-b99f71aeda18","subtype":"Figure","type":"Plot"}},"id":"890f0d24-b802-4c31-b54f-8fd34ca98868","type":"BoxZoomTool"},{"attributes":{},"id":"e7026fcc-3eef-46b1-aacb-1db028d3fd30","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"88255157-9f42-4986-9dd9-a9f469159370","type":"PanTool"},{"id":"72fb421f-b3a4-4ed2-ba48-bd7c9dfb17fe","type":"WheelZoomTool"},{"id":"890f0d24-b802-4c31-b54f-8fd34ca98868","type":"BoxZoomTool"},{"id":"d6bf888f-9e00-450c-a759-b8a004f5b29e", ...

# %% [markdown]
# # Lesson 3: More SQL stuff

# %% [markdown]
# **Simple substring matching: the `LIKE` operator.** Suppose we just want to look at the counts for all complaints that have the word `noise` in them. You can use the `LIKE` operator combined with the string wildcard, `%`, to look for case-insensitive substring matches.

# %%
query = '''
  SELECT ComplaintType AS type, COUNT(*) AS freq
    FROM data
    WHERE ComplaintType LIKE '%noise%'
    GROUP BY type
    ORDER BY -freq
'''

df_noisy = pd.read_sql_query(query, disk_engine)
df_noisy
# Out:
#                        type   freq
# 0                     Noise  54165
# 1   Noise - Street/Sidewalk  48436
# 2        Noise - Commercial  42422
# 3           Noise - Vehicle  18370
# 4              Noise - Park   4020
# 5        Noise - Helicopter   1715
# 6  Noise - House of Worship   1143
# 7    Collection Truck Noise    184

# %% [markdown]
# **Exercise 2** (2 points). Create a string variable, `query`, that contains an SQL query that will return the top 10 cities with the largest number of complaints, in descending order. It should return a table with two columns, one named `name` holding the name of the city, and one named `freq` holding the number of complaints by that city.

# %%
del query

query = '''
    SELECT City AS name, COUNT(*) AS freq
    FROM data
    GROUP BY name
    ORDER BY freq DESC
    LIMIT 10
'''

# Runs your `query`:
df_whiny_cities = pd.read_sql_query(query, disk_engine)
df_whiny_cities
# Out:
#             name    freq
# 0       BROOKLYN  579363
# 1       NEW YORK  385655
# 2          BRONX  342533
# 3           None  168692
# 4  STATEN ISLAND   92509
# 5        Jamaica   30435
# 6       Flushing   20708
# 7        Astoria   18068
# 8        JAMAICA   16248
# 9       FLUSHING   14796

# %%
# Test cell: `whiny_cities__test`

assert df_whiny_cities['name'][0] == 'BROOKLYN'
assert df_whiny_cities['name'][1] == 'NEW YORK'
assert df_whiny_cities['name'][2] == 'BRONX'
assert df_whiny_cities['name'][3] is None
assert df_whiny_cities['name'][4] == 'STATEN ISLAND'

print ("\n(Passed partial test.)")
# Out:
# (Passed partial test.)

# %% [markdown]
# You should notice two odd bits: cities are treated in a _case-sensitive_ manner and `None` appears as a city. (Presumably this setting occurs when a complaint is non-localized or the city is not otherwise specified.)

# %% [markdown]
# **Case-insensitive grouping: `COLLATE NOCASE`.** One way to carry out the preceding query in a case-insensitive way is to add a `COLLATE NOCASE` qualifier to the `GROUP BY` clause.
#
# Let's filter out the 'None' cases as well, while we are at it. We can use `<>` to denote "not equal to" in SQL.

# %%
query = '''
  SELECT City AS name
    FROM data
    WHERE name <> 'None'
    GROUP BY name COLLATE NOCASE
    ORDER BY -COUNT(*)
    LIMIT 10
'''
df_whiny_cities2 = pd.read_sql_query(query, disk_engine)
df_whiny_cities2
# Out:
#             name
# 0       BROOKLYN
# 1       NEW YORK
# 2          BRONX
# 3  STATEN ISLAND
# 4        Jamaica
# 5       Flushing
# 6        ASTORIA
# 7      Ridgewood
# 8       Woodside
# 9         Corona

# %% [markdown]
# Brooklynites are complainers, evidently.
#
# Lastly, for later use, let's save the names of just the top seven (7) cities by numbers of complaints.

# %%
TOP_CITIES = list(df_whiny_cities2.head(7)['name'])
TOP_CITIES
# Out:
# ['BROOKLYN',
#  'NEW YORK',
#  'BRONX',
#  'STATEN ISLAND',
#  'Jamaica',
#  'Flushing',
#  'ASTORIA']

# %% [markdown]
# **Exercise 3** (1 point). Implement a function that takes a list of strings, `str_list`, and returns a single string consisting of each value, `str_list[i]`, enclosed by double-quotes and separated by a comma-space delimiters. For example, if
#
# ```python
#    assert str_list == ['a', 'b', 'c', 'd']
# ```
#
# then
#
# ```python
#    assert strs_to_args(str_list) == '"a", "b", "c", "d"'
# ```
#
# > **Tip.** Try to avoid manipulating the input `str_list` directly and returning the updated `str_list`. This may result in your function adding `""` to the strings in your list each time the function is used (which will be more than once in this notebook!)

# %%
def strs_to_args(str_list):
    assert type (str_list) is list
    assert all ([type (s) is str for s in str_list])
    
    s=''
    for item in str_list:
        s += '"'
        s += item
        s += '", '
    s = s[:-2]
    return s

# %%
# Test cell: `strs_to_args__test`

print ("Your solution, applied to TOP_CITIES:", strs_to_args(TOP_CITIES))

TOP_CITIES_as_args = strs_to_args(TOP_CITIES)
assert TOP_CITIES_as_args.lower() == \
       '"BROOKLYN", "NEW YORK", "BRONX", "STATEN ISLAND", "Jamaica", "Flushing", "ASTORIA"'.lower ()
    
print ("\n(Passed.)")
# Out:
# Your solution, applied to TOP_CITIES: "BROOKLYN", "NEW YORK", "BRONX", "STATEN ISLAND", "Jamaica", "Flushing", "ASTORIA"
#
# (Passed.)

# %% [markdown]
# **Exercise 4** (3 points). Suppose we want to look at the number of complaints by type _and_ by city **for only the top cities**, i.e., those in the list `TOP_CITIES` computed above. Execute an SQL query to produce a tibble named `df_complaints_by_city` with the variables {`complaint_type`, `city_name`, `complaint_count`}.

# %%
query = '''
        SELECT ComplaintType as complaint_type,
                City as city_name,
                COUNT(*) as complaint_count
        FROM data
        WHERE city_name in ({})
        GROUP BY complaint_type, city_name
        ORDER BY complaint_count DESC
        '''.format(strs_to_args(TOP_CITIES))

df_complaints_by_city = pd.read_sql_query(query, disk_engine)

# Previews the results of your query:
display(df_complaints_by_city.head(10))
# Out:
#          complaint_type city_name  complaint_count
# 0        HEAT/HOT WATER     BRONX            79690
# 1        HEAT/HOT WATER  BROOKLYN            72410
# 2        HEAT/HOT WATER  NEW YORK            55545
# 3      Street Condition  BROOKLYN            34426
# 4      Blocked Driveway  BROOKLYN            34351
# 5       Illegal Parking  BROOKLYN            30495
# 6  UNSANITARY CONDITION  BROOKLYN            28668
# 7                 Noise  NEW YORK            25943
# 8         PAINT/PLASTER  BROOKLYN            24240
# 9  UNSANITARY CONDITION     BRONX            23440

# %%
# Test cell: `df_complaints_by_city__test`

print("Reading instructor's solution...")
df_complaints_by_city_soln = pd.read_csv('df_complaints_by_city_soln.csv')

print("Checking...")
assert tibbles_are_equivalent(df_complaints_by_city,
                              df_complaints_by_city_soln)

print("\n(Passed.)")
del df_complaints_by_city_soln
# Out:
# Reading instructor's solution...
# Checking...
#
# (Passed.)

# %% [markdown]
# Let's use Bokeh to visualize the results as a stacked bar chart.

# %%
# Let's consider only the top 25 complaints (by total)
top_complaints = df_complaint_freq[:25]
print("Top complaints:")
display(top_complaints)
# Out:
# Top complaints:
#                              type    freq
# 0                  HEAT/HOT WATER  241430
# 1                Street Condition  124347
# 2          Street Light Condition   98577
# 3                Blocked Driveway   95080
# 4                 Illegal Parking   83961
# 5            UNSANITARY CONDITION   81394
# 6                   PAINT/PLASTER   69929
# 7                    Water System   69209
# 8                        PLUMBING   55445
# 9                           Noise   54165
# 10        Noise - Street/Sidewalk   48436
# 11       Traffic Signal Condition   44229
# 12             Noise - Commercial   42422
# 13                    DOOR/WINDOW   39695
# 14                     WATER LEAK   36149
# 15               Dirty Conditions   35122
# 16                          Sewer   33628
# 17           Sanitation Condition   31260
# 18         DOF Literature Request   30326
# 19                       ELECTRIC   30248
# 20                         Rodent   28454
# 21                FLOORING/STAIRS   27007
# 22  General Construction/Plumbing   26861
# 23                   Building/Use   25807
# 24              Broken Muni Meter   25428

# %%
df_complaints_by_city.head()
# Out:
#      complaint_type city_name  complaint_count
# 0    HEAT/HOT WATER     BRONX            79690
# 1    HEAT/HOT WATER  BROOKLYN            72410
# 2    HEAT/HOT WATER  NEW YORK            55545
# 3  Street Condition  BROOKLYN            34426
# 4  Blocked Driveway  BROOKLYN            34351

# %%
# Plot subset of data corresponding to the top complaints
df_plot = top_complaints.merge(df_complaints_by_city,
                               left_on=['type'],
                               right_on=['complaint_type'],
                               how='left')
df_plot.dropna(inplace=True)
print("Data to plot (first few rows):")
display(df_plot.head())
print("...")
# Out:
# Data to plot (first few rows):
#              type    freq  complaint_type city_name  complaint_count
# 0  HEAT/HOT WATER  241430  HEAT/HOT WATER     BRONX          79690.0
# 1  HEAT/HOT WATER  241430  HEAT/HOT WATER  BROOKLYN          72410.0
# 2  HEAT/HOT WATER  241430  HEAT/HOT WATER  NEW YORK          55545.0
# 3  HEAT/HOT WATER  241430  HEAT/HOT WATER   Jamaica           3376.0
# 4  HEAT/HOT WATER  241430  HEAT/HOT WATER  Flushing           2741.0
# ...

# %%
# Some code to render a Bokeh stacked bar chart

kwargs_figure = {'title': "Distribution of the top 25 complaints among top 7 cities with the most complaints",
                 'width': 800,
                 'height': 400,
                 'tools': "hover,crosshair,pan,box_zoom,wheel_zoom,save,reset,help"}

def plot_complaints_stacked_by_city(df, y='complaint_count'):
    p = make_stacked_bar(df, 'complaint_type', 'city_name', y,
                         x_labels=list(top_complaints['type']), bar_labels=TOP_CITIES,
                         kwargs_figure=kwargs_figure)
    p.xaxis.major_label_orientation = 0.66
    from bokeh.models import HoverTool
    hover_tool = p.select(dict(type=HoverTool))
    hover_tool.tooltips = [("y", "$y{int}")]
    return p

show(plot_complaints_stacked_by_city(df_plot))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2f813a99-3e79-4454-907f-7946033204c0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2f813a99-3e79-4454-907f-7946033204c0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2f813a99-3e79-4454-907f-7946033204c0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2f813a99-3e79-4454-907f-7946033204c0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f0bd1f60-a083-48a4-b866-9bf2ff2c5e33":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5a888cc4-e31e-400b-bdad-55ff424fef24","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"96c04d4b-434f-4ad8-b70e-460ddc09c3e5","type":"CategoricalAxis"}],"left":[{"id":"e44ec076-4ec0-4f87-9e0a-9c1cf01cca0a","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"96c04d4b-434f-4ad8-b70e-460ddc09c3e5","type":"CategoricalAxis"},{"id":"de30a47c-bc43-4603-9e5a-207416ba715a","type":"Grid"},{"id":"e44ec076-4ec0-4f87-9e0a-9c1cf01cca0a","type":"LinearAxis"},{"id":"96547b48-a744-4d42-a492-baab9170cae1","type":"Grid"},{"id":"5a888cc4-e31e-400b-bdad-55ff424fef24","type":"BoxAnnotation"},{"id":"3142400e-890e-46b8-a2f8-04a4d878e543","type":"Legend"},{"id":"e0e3c9e1-c5d5-4037-92dc-7466949bee1d","type":"GlyphRenderer"},{"id":"02a53615-7dbb-4923-8dc9-a21402c4ee54","type":"GlyphRenderer"},{"id":"0c78c263-86d5-48f9-8434-a24ccabf1315","type":"GlyphRenderer"},{"id":"ecf8734d-5893-4d4a-a722-cee0c9803f5d","type":"GlyphRenderer"},{"id":"970dc77b-59a0-43dc-a0e7-daf8b03cf3cc","type":"GlyphRenderer"},{"id":"6b6e9d11-9435-4261-b07f-b1fb3497d63b","type":"GlyphRenderer"},{"id":"00efc2f6-8fc6-4162-91c5-30266693445e","type":"GlyphRenderer"}],"title":{"id":"0ee8b7e6-545b-447b-a7eb-4faee0ffd1ed","type":"Title"},"tool_events":{"id":"90c5d862-33b3-4716-98ab-add02936dc01","type":"ToolEvents"},"toolbar":{"id":"97779c0f-4158-4547-95cf-80c036ab6750","type":"Toolbar"},"x_range":{"id":"518778ec-6f1a-4212-acf0-12ef05e3d85d","type":"FactorRange"},"x_scale":{"id":"8c14ea6b-78ae-43f1-b1a3-109ad79a2401","type":"CategoricalScale"},"y_range":{"id":"0f06c11b-d640-4cd5-862b-96aebe42bb9f","type":"DataRange1d"},"y_scale":{"id":"ce0daf51-1a34-411d-90db-0238902638a0","type":"LinearScale"}},"id":"7c1a4b7f-fa51-4aeb-b922-c1fa1ff8c186","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"ce0daf51-1a34-411d-90db-0238902638a0","type":"LinearScale"},{"attributes":{"callback":null,"plot":{"id":"7c1a4b7f-fa51-4aeb-b922-c1fa1ff8c186","subtype":"Figure","type":"Plot"},"tooltips":[["y","$y{int}"]]},"id":"f789cc49-6f4e-407a-8924-f78d2e558322","type":"HoverTool"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.25},"x":{"field":"x"}},"id":"751542a1-439c-4aec-ad13-a85036525f95","type":"VBar"},{"attributes":{"data_source":{"id":"9d89630c-8065-45f6-a9c0-c96cf1408e9a","type":"ColumnDataSource"},"glyph":{"id":"edfdc946-e0c4-40d1-a177-d6382eed2f68","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d1d205c4-2438-443c-81c5-8a474371b1ea","type":"VBar"},"selection_glyph":null},"id":"0c78c263-86d5-48f9-8434-a24ccabf1315","type":"GlyphRenderer"},{"attributes":{"bottom":{"field":"bottom"},"fill_color":{"value":"#e6ab02"},"line_color":{"value":"#e6ab02"},"top":{"field":"top"},"width":{"value":0.25},"x":{"field":"x"}},"id":"4167c501-520e-44f1-b3cf-ec13992d4823","type":"VBar"},{"attributes":{"data_source":{"id":"e1e67a97-011e-4b11-9651-994ee21c73ee","type":"ColumnDataSource"},"glyph":{"id":"80ebe5a9-0e94-4dec-b4df-adddb7b72878","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"751542a1-439c-4aec-ad13-a85036525f95","type":"VBar"},"selection_glyph":null},"id":"970dc77b-59a0-43dc-a0e7-daf8b03cf3cc","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7cd1ed56-fbe5-4a8a-9fbc-0416aa9e2eb9","type":"ColumnDataSource"},"glyph":{"id":"393dd715-12df-47e0-bc0c-ed36d3a82ee0","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"87aa770e- ...

# %% [markdown]
# **Exercise 5** (2 points). Suppose we want to create a different stacked bar plot that shows, for each complaint type $t$ and city $c$, the fraction of all complaints of type $t$ that occurred in city $c$. Store your result in a dataframe named `df_plot_fraction`. It should have the same columns as `df_plot`, **except** that the `complaint_count` column should be replaced by one named `complaint_frac`, which holds the fractional values.
#
# > The test cell will create the chart in addition to checking your result. Note that the normalized bars will not necessarily add up to 1; why not?

# %%
# Plot subset of data corresponding to the top complaints
df_plot_fraction = top_complaints.merge(df_complaints_by_city,
                               left_on=['type'],
                               right_on=['complaint_type'],
                               how='left')
df_plot_fraction.dropna(inplace=True)
df_plot_fraction['complaint_frac'] = df_plot_fraction['complaint_count'] / df_plot_fraction['freq']
df_plot_fraction = df_plot_fraction.drop(axis = 1, labels = 'complaint_count')
df_plot_fraction.head()
# Out:
#              type    freq  complaint_type city_name  complaint_frac
# 0  HEAT/HOT WATER  241430  HEAT/HOT WATER     BRONX        0.330075
# 1  HEAT/HOT WATER  241430  HEAT/HOT WATER  BROOKLYN        0.299921
# 2  HEAT/HOT WATER  241430  HEAT/HOT WATER  NEW YORK        0.230067
# 3  HEAT/HOT WATER  241430  HEAT/HOT WATER   Jamaica        0.013983
# 4  HEAT/HOT WATER  241430  HEAT/HOT WATER  Flushing        0.011353

# %%
# Test cell: `norm_above_test`

df_plot_stacked_fraction = cast(df_plot_fraction, key='city_name', value='complaint_frac')

if False:
    df_plot_stacked_fraction.to_csv('df_plot_stacked_fraction_soln.csv', index=False)

show(plot_complaints_stacked_by_city(df_plot_fraction, y='complaint_frac'))

def all_tol(x, tol=1e-14):
    return all([abs(i) <= tol for i in x])

df_plot_fraction_soln = canonicalize_tibble(pd.read_csv('df_plot_fraction_soln.csv'))
df_plot_fraction_yours = canonicalize_tibble(df_plot_fraction)

nonfloat_cols = df_plot_fraction.columns.difference(['complaint_frac'])
assert tibbles_are_equivalent(df_plot_fraction_yours[nonfloat_cols],
                              df_plot_fraction_soln[nonfloat_cols])
assert all(abs(df_plot_fraction_yours['complaint_frac'] - df_plot_fraction_soln['complaint_frac']) <= 1e-13)

print("\n(Passed!)")
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="67a6154a-5bfc-486e-96a9-bdad9c9265a8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("67a6154a-5bfc-486e-96a9-bdad9c9265a8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("67a6154a-5bfc-486e-96a9-bdad9c9265a8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '67a6154a-5bfc-486e-96a9-bdad9c9265a8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e7ada9d6-370b-49ae-951a-a68a8d4ae164":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":{"__ndarray__":"","dtype":"float64","shape":[24]},"x":["Blocked Driveway","Broken Muni Meter","Building/Use","DOOR/WINDOW","Dirty Conditions","ELECTRIC","FLOORING/STAIRS","General Construction/Plumbing","HEAT/HOT WATER","Illegal Parking","Noise","Noise - Commercial","Noise - Street/Sidewalk","PAINT/PLASTER","PLUMBING","Rodent","Sanitation Condition","Sewer","Street Condition","Street Light Condition","Traffic Signal Condition","UNSANITARY CONDITION","WATER LEAK","Water System"]}},"id":"b674d6f2-234e-42c9-9250-2ced36940518","type":"ColumnDataSource"},{"attributes":{"label":{"value":"STATEN ISLAND"},"renderers":[{"id":"705e7ef1-050f-49b4-bc8f-6241146c3031","type":"GlyphRenderer"}]},"id":"be654295-ebfa-460f-bf9b-064eb82d6b1d","type":"LegendItem"},{"attributes":{"label":{"value":"NEW YORK"},"renderers":[{"id":"7e450c57-ff8a-458b-9a93-8bb52777961e","type":"GlyphRenderer"}]},"id":"1c050daa-770d-4694-b5c2-d7280c4abae9","type":"LegendItem"},{"attributes":{},"id":"2198b9ff-5acc-4cd6-86e9-b42379710bff","type":"LinearScale"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.25},"x":{"field":"x"}},"id":"23a375f0-5485-4e5b-9b0d-96b0bc245631","type":"VBar"},{"attributes":{"below":[{"id":"e2403480-6785-47d2-9bbb-a71aa29dff37","type":"CategoricalAxis"}],"left":[{"id":"26af733c-a26a-4cc1-9f7b-027beb8ec0e1","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"e2403480-6785-47d2-9bbb-a71aa29dff37","type":"CategoricalAxis"},{"id":"0d140087-cdd8-40db-a361-bb0cce6db9af","type":"Grid"},{"id":"26af733c-a26a-4cc1-9f7b-027beb8ec0e1","type":"LinearAxis"},{"id":"fe374d72-5f1d-4437-821d-78c6ea44bf1a","type":"Grid"},{"id":"3adaecd3-7deb-439a-ba40-7d21fcbcb318","type":"BoxAnnotation"},{"id":"1d297ac1-ec30-4849-8f42-b872d6a5b271","type":"Legend"},{"id":"345fa3af-5f9b-4262-b34a-a4973dff6940","type":"GlyphRenderer"},{"id":"9178e4be-9fd8-4d84-850c-add22bbf4720","type":"GlyphRenderer"},{"id":"331b1d23-3a65-4ce0-acfd-a4e1ebc09362","type":"GlyphRenderer"},{"id":"9d91278b-9593-4883-80ae-f5166b1ba13e","type":"GlyphRenderer"},{"id":"b9a80b23-7909-465d-b3c9-515d588c809e","type":"GlyphRenderer"},{"id":"7e450c57-ff8a-458b-9a93-8bb52777961e","type":"GlyphRenderer"},{"id":"705e7ef1-050f-49b4-bc8f-6241146c3031","type":"GlyphRenderer"}],"title":{"id":"51bd6bfd-f238-4ab5-ac79-78eccbab38fc","type":"Title"},"tool_events":{"id":"ca5a01f0-9c5a-452f-9558-bcd034d9ac2c","type":"ToolEvents"},"toolbar":{"id":"524337f2-2e36-421d-a282-70e7b4b9e589","type":"Toolbar"},"x_range":{"id":"4168b4ed-8cdc-4d43-b7c7-6d2938a344e2","type":"FactorRange"},"x_scale":{"id":"e0235290-24e3-4e4b-8257-475e53cb75af","type":"CategoricalScale"},"y_range":{"id":"d09c2283-23ff-4f17-864f-1ce0de53108a","type":"DataRange1d"},"y_scale":{"id":"2198b9ff-5acc-4cd6-86e9-b42379710bff","type":"LinearScale"}},"id":"67c75c2a-3228-4059-b24c-7c5a7bbf6818","subtype":"Figure","type":"Plot"},{"attributes":{"label":{"value":"BRONX"},"renderers":[{"id":"9178e4be-9fd8-4d84-850c-add22bbf4720","type":"GlyphRenderer"}]},"id":"f3098f5b-eaaf-4489-beb3-a797e596c8ae","type":"LegendItem"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.25},"x":{"field":"x"}},"id":"4ab2d19f-4cc7-453f-a411-af4802cd9756","type":"VBar"},{"attributes":{"callback":null,"column_names":["x","bottom","top"],"data":{"bottom" ...
# (Passed!)

# %% [markdown]
# ## Dates and times in SQL
#
# Recall that the input data had a column with timestamps corresponding to when someone submitted a complaint. Let's quickly summarize some of the features in SQL and Python for reasoning about these timestamps.

# %% [markdown]
# The `CreatedDate` column is actually a specially formatted date and time stamp, where you can query against by comparing to strings of the form, `YYYY-MM-DD hh:mm:ss`.
#
# For example, let's look for all complaints on September 15, 2015.

# %%
query = '''
  SELECT ComplaintType, CreatedDate, City
    FROM data
    WHERE CreatedDate >= "2015-09-15 00:00:00.0"
      AND CreatedDate < "2015-09-16 00:00:00.0"
    ORDER BY CreatedDate
'''
df = pd.read_sql_query (query, disk_engine)
df
# Out:
#                       ComplaintType                 CreatedDate  \
# 0                   Illegal Parking  2015-09-15 00:01:23.000000
# 1                  Blocked Driveway  2015-09-15 00:02:29.000000
# 2                    Taxi Complaint  2015-09-15 00:02:34.000000
# 3             Opinion for the Mayor  2015-09-15 00:03:07.000000
# 4             Opinion for the Mayor  2015-09-15 00:03:07.000000
# 5                   Noise - Vehicle  2015-09-15 00:03:14.000000
# 6                  Dirty Conditions  2015-09-15 00:04:00.000000
# 7                Noise - Commercial  2015-09-15 00:04:22.000000
# 8              UNSANITARY CONDITION  2015-09-15 00:04:24.000000
# 9                     PAINT/PLASTER  2015-09-15 00:04:24.000000
# 10                         PLUMBING  2015-09-15 00:04:24.000000
# 11                       WATER LEAK  2015-09-15 00:04:24.000000
# 12                         Graffiti  2015-09-15 00:04:39.000000
# 13                         Graffiti  2015-09-15 00:05:32.000000
# 14          Noise - Street/Sidewalk  2015-09-15 00:05:41.000000
# 15               Noise - Commercial  2015-09-15 00:06:38.000000
# 16                         Graffiti  2015-09-15 00:06:46.000000
# 17                  Illegal Parking  2015-09-15 00:07:09.000000
# 18                         Graffiti  2015-09-15 00:08:49.000000
# 19                         Graffiti  2015-09-15 00:10:13.000000
# 20                  Illegal Parking  2015-09-15 00:11:20.000000
# 21                         Graffiti  2015-09-15 00:11:26.000000
# 22          Noise - Street/Sidewalk  2015-09-15 00:11:27.000000
# 23                 Animal in a Park  2015-09-15 00:11:36.000000
# 24                     Animal Abuse  2015-09-15 00:11:41.000000
# 25                 Blocked Driveway  2015-09-15 00:12:33.000000
# 26             UNSANITARY CONDITION  2015-09-15 00:12:44.000000
# 27          Noise - Street/Sidewalk  2015-09-15 00:13:54.000000
# 28                  Noise - Vehicle  2015-09-15 00:15:49.000000
# 29                           Rodent  2015-09-15 00:18:07.000000
# ..                              ...                         ...
# 88   Unsanitary Animal Pvt Property  2015-09-15 01:24:45.000000
# 89           DOT Literature Request  2015-09-15 01:25:41.000000
# 90               Noise - Commercial  2015-09-15 01:26:03.000000
# 91          Noise - Street/Sidewalk  2015-09-15 01:28:33.000000
# 92          Noise - Street/Sidewalk  2015-09-15 01:30:09.000000
# 93               Noise - Commercial  2015-09-15 01:31:26.000000
# 94            Opinion for the Mayor  2015-09-15 01:31:55.000000
# 95               Noise - Commercial  2015-09-15 01:34:18.000000
# 96               Noise - Commercial  2015-09-15 01:36:25.000000
# 97                 Street Condition  2015-09-15 01:37:35.000000
# 98                           Rodent  2015-09-15 01:37:42.000000
# 99               Noise - Commercial  2015-09-15 01:40:08.000000
# 100              Noise - Commercial  2015-09-15 01:45:15.000000
# 101                 Noise - Vehicle  2015-09-15 01:47:16.000000
# 102              Noise - Commercial  2015-09-15 01:47:56.000000
# 103         Noise - Street/Sidewalk  2015-09-15 01:48:19.000000
# 104                Blocked Driveway  2015-09-15 01:51:04.000000
# 105         Noise - Street/Sidewalk  2015-09-15 01:51:14.000000
# 106                 Illegal Parking  2015-09-15 01:52:10.000000
# 107                 Illegal Parking  2015-09-15 01:53:19.000000
# 108              Noise - Commercial  2015-09-15 01:56:32.000000
# 109              Food Establishment  2015-09-15 01:57:38.000000
# 110                    Noise - Park  2015-09-15 01:57:39.000000
# 111                Blocked Driveway  2015-09-15 01:58:05.000000
# 112               Highway Condition  2015-09-15 02:07:01.000000
# 113      Homeless Person Assistance  2015-09-15 02:08:01.000000
# 114              Noise - Commercial  2015-09-15 02:09:46.000000
# 115         Noise - Street/Sidewalk  2015-09-15 02:11:19.000000
# 116         Noise - Street/Sidewalk  2015-09-15 02:12:49.000000
# 117                 Illegal Parking  2015-09-15 02:14:04.000000
#
#                City
# 0              None
# 1         REGO PARK
# 2          NEW YORK
# 3              None
# 4              None
# 5          BROOKLYN
# 6          BROOKLYN
# 7          NEW YORK
# 8          NEW YORK
# 9          NEW YORK
# 10            BRONX
# 11         NEW YORK
# 12            BRONX
# 13            BRONX
# 14            BRONX
# 15         NEW YORK
# 16            BRONX
# 17         ROSEDALE
# 18            BRONX
# 19            BRONX
# 20   QUEENS VILLAGE
# 21            BRONX
# 22         BROOKLYN
# 23         ELMHURST
# 24         BROOKLYN
# 25         BROOKLYN
# 26         BROOKLYN
# 27         BROOKLYN
# 28         NEW YORK
# 29         NEW YORK
# ..              ...
# 88         BROOKLYN
# 89             None
# 90         NEW YORK
# 91         NEW YORK
# 92         NEW YORK
# 93      KEW GARDENS
# 94             None
# 95          ASTORIA
# 96         NEW YORK
# 97         NEW YORK
# 98         BROOKLYN
# 99         BROOKLYN
# 100        NEW YORK
# 101        BROOKLYN
# 102        NEW YORK
# 103        BROOKLYN
# 104           BRONX
# 105        BROOKLYN
# 106   STATEN ISLAND
# 107           BRONX
# 108        NEW YORK
# 109        BROOKLYN
# 110        NEW YORK
# 111        ELMHURST
# 112   STATEN ISLAND
# 113        NEW YORK
# 114           BRONX
# 115        NEW YORK
# 116        NEW YORK
# 117            None
#
# [118 rows x 3 columns]

# %% [markdown]
# This next example shows how to extract just the hour from the time stamp, using SQL's `strftime()`.

# %%
query = '''
  SELECT CreatedDate, strftime ('%H', CreatedDate) AS Hour, ComplaintType
    FROM data
    LIMIT 5
'''
df = pd.read_sql_query (query, disk_engine)
df
# Out:
#                   CreatedDate Hour               ComplaintType
# 0  2015-09-15 02:14:04.000000   02             Illegal Parking
# 1  2015-09-15 02:12:49.000000   02     Noise - Street/Sidewalk
# 2  2015-09-15 02:11:19.000000   02     Noise - Street/Sidewalk
# 3  2015-09-15 02:09:46.000000   02          Noise - Commercial
# 4  2015-09-15 02:08:01.000000   02  Homeless Person Assistance

# %% [markdown]
# **Exercise 6** (3 points). Construct a tibble called `df_complaints_by_hour`, which contains the total number of complaints during a given hour of the day. That is, the variables should be {`hour`, `count`} where each observation is the total number of complaints (`count`) that occurred during a given `hour`.
#
# > Interpret `hour` as follows: when `hour` is `02`, that corresponds to the open time interval [`02:00:00`, `03:00:00.0`).

# %%
query = '''
  SELECT strftime ('%H', CreatedDate) AS hour, Count(*) as count
    FROM data
    GROUP BY hour
'''
df_complaints_by_hour = pd.read_sql_query (query, disk_engine)

# Displays your answer:
display(df_complaints_by_hour)
# Out:
#    hour   count
# 0    00  564703
# 1    01   23489
# 2    02   15226
# 3    03   10164
# 4    04    8692
# 5    05   10224
# 6    06   23051
# 7    07   42273
# 8    08   73811
# 9    09  100077
# 10   10  114079
# 11   11  115849
# 12   12  102392
# 13   13  100970
# 14   14  105425
# 15   15  100271
# 16   16   86968
# 17   17   69920
# 18   18   67467
# 19   19   57637
# 20   20   54997
# 21   21   53126
# 22   22   52076
# 23   23   47113

# %%
# Test cell: `df_complaints_by_hour_test`
    
print ("Reading instructor's solution...")
if False:
    df_complaints_by_hour_soln.to_csv('df_complaints_by_hour_soln.csv', index=False)
df_complaints_by_hour_soln = pd.read_csv ('df_complaints_by_hour_soln.csv')
display (df_complaints_by_hour_soln)

df_complaints_by_hour_norm = df_complaints_by_hour.copy ()
df_complaints_by_hour_norm['hour'] = \
    df_complaints_by_hour_norm['hour'].apply (int)
assert tibbles_are_equivalent (df_complaints_by_hour_norm,
                               df_complaints_by_hour_soln)
print ("\n(Passed.)")
# Out:
# Reading instructor's solution...
#     hour   count
# 0      0  564703
# 1      1   23489
# 2      2   15226
# 3      3   10164
# 4      4    8692
# 5      5   10224
# 6      6   23051
# 7      7   42273
# 8      8   73811
# 9      9  100077
# 10    10  114079
# 11    11  115849
# 12    12  102392
# 13    13  100970
# 14    14  105425
# 15    15  100271
# 16    16   86968
# 17    17   69920
# 18    18   67467
# 19    19   57637
# 20    20   54997
# 21    21   53126
# 22    22   52076
# 23    23   47113
# (Passed.)

# %% [markdown]
# Let's take a quick look at the hour-by-hour breakdown above.

# %%
p = make_barchart(df_complaints_by_hour, 'hour', 'count',
                  {'title': 'Complaints by hour',
                   'plot_width': 800, 'plot_height': 320})
show(p)
# Out:
# /usr/local/lib/python3.5/dist-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b55ef98d-1f76-4cf5-be69-90786c4c10e7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b55ef98d-1f76-4cf5-be69-90786c4c10e7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b55ef98d-1f76-4cf5-be69-90786c4c10e7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b55ef98d-1f76-4cf5-be69-90786c4c10e7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"02c2f3c6-829b-4a78-b58f-c2288055f086":{"roots":{"references":[{"attributes":{"data_source":{"id":"902002bd-8567-40d1-a0ee-751a149fb373","type":"ColumnDataSource"},"glyph":{"id":"ea82f322-6027-48f7-a26b-806eb16aa243","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3906f3e0-1e5e-4d7b-aa87-738f75bc13de","type":"VBar"},"selection_glyph":null},"id":"3e76ee0f-e49e-4b66-a167-158f983d3953","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.9},"x":{"field":"x"}},"id":"ea82f322-6027-48f7-a26b-806eb16aa243","type":"VBar"},{"attributes":{},"id":"25dc9831-002e-4283-a53f-4d84a08433b6","type":"BasicTicker"},{"attributes":{},"id":"ae1b1449-ce17-4f23-857f-b7e54b338463","type":"CategoricalScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a90b2626-0982-4f51-ba87-58b698b5a877","type":"PanTool"},{"id":"72d346d5-9f6a-4d87-bb4e-805d38ed9729","type":"WheelZoomTool"},{"id":"392debcb-36db-437c-bc78-ac8e9f96c7ff","type":"BoxZoomTool"},{"id":"91a6beef-2579-4c8d-9ad8-10d3c3abce91","type":"SaveTool"},{"id":"de15808b-80b4-47b7-89c5-2ef1cd892ef9","type":"ResetTool"},{"id":"75795c39-6e2a-44cb-9ee7-2e5e8d7d4c60","type":"HelpTool"}]},"id":"316a4d81-0d16-486d-8cb1-1e6533306a1e","type":"Toolbar"},{"attributes":{"below":[{"id":"f1f3bf3b-c194-4c03-bea1-c4e4d5dbf517","type":"CategoricalAxis"}],"left":[{"id":"395142eb-5fec-43f8-841c-c53231567809","type":"LinearAxis"}],"plot_height":320,"plot_width":800,"renderers":[{"id":"f1f3bf3b-c194-4c03-bea1-c4e4d5dbf517","type":"CategoricalAxis"},{"id":"289bee9c-019d-486c-b4af-601125642a46","type":"Grid"},{"id":"395142eb-5fec-43f8-841c-c53231567809","type":"LinearAxis"},{"id":"5e3aaeaf-7056-4658-aef5-2dfd653e3292","type":"Grid"},{"id":"3d6a6c88-666f-43a5-9a2e-d43100d66d41","type":"BoxAnnotation"},{"id":"3e76ee0f-e49e-4b66-a167-158f983d3953","type":"GlyphRenderer"}],"title":{"id":"83b2ac51-05fa-410d-8baa-019e1d1b643b","type":"Title"},"tool_events":{"id":"08f3956e-2a0a-4bbc-afcb-6e22984311de","type":"ToolEvents"},"toolbar":{"id":"316a4d81-0d16-486d-8cb1-1e6533306a1e","type":"Toolbar"},"x_range":{"id":"c5c7bf0d-9c31-491b-bdfa-6d8d59c641c5","type":"FactorRange"},"x_scale":{"id":"ae1b1449-ce17-4f23-857f-b7e54b338463","type":"CategoricalScale"},"y_range":{"id":"0f0e0ddf-639a-4b8e-9ff1-9eee913b59d2","type":"DataRange1d"},"y_scale":{"id":"7af562b6-ac46-437b-b2fd-9d04dfe0efcb","type":"LinearScale"}},"id":"d54acd94-a1c9-462a-b5e2-078302edb563","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"7af562b6-ac46-437b-b2fd-9d04dfe0efcb","type":"LinearScale"},{"attributes":{},"id":"2dd495ad-1bfc-4a04-a67f-afffd2ffb711","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d54acd94-a1c9-462a-b5e2-078302edb563","subtype":"Figure","type":"Plot"}},"id":"de15808b-80b4-47b7-89c5-2ef1cd892ef9","type":"ResetTool"},{"attributes":{"callback":null},"id":"0f0e0ddf-639a-4b8e-9ff1-9eee913b59d2","type":"DataRange1d"},{"attributes":{"plot":{"id":"d54acd94-a1c9-462a-b5e2-078302edb563","subtype":"Figure","type":"Plot"}},"id":"75795c39-6e2a-44cb-9ee7-2e5e8d7d4c60","type":"HelpTool"},{"attributes":{},"id":"2ff15e6d-ee8f-4d7a-9920-6e96bf02a6d4","type":"CategoricalTicker"},{"attributes":{"formatter":{"id":"a190ac2f-d88d-424b-a60f-50fbe2e4e0af","type":"CategoricalTickFormatter"},"plot":{"id":"d54acd94-a1c9-462a-b5e2-078302edb563","subtype":"Figure","type":"Plot"},"ticker":{"id":"2ff15e6d-ee8f-4d7a-9920-6e96bf02a6d4","type":"CategoricalTicker"}},"id":"f1f3bf3b-c194-4c03-bea1-c4e4d5dbf517","type":"CategoricalAxis"},{"attributes":{"dimension":1,"plot":{"id":"d54acd94-a1c9-462a-b5e2-078302edb563","subtype":"Figure","type":"Plot"},"ticker":{"id":"25dc9831-002e-4283-a53f-4d84a08433b6","type":"BasicTicker"}},"id":"5e3aaeaf-7056-4658-aef5-2dfd653e3292","type":"Grid"},{"attributes":{"plot":{"id":"d54acd94-a1c9-462a-b5e2-078302edb563","s ...

# %% [markdown]
# An unusual aspect of these data are the excessively large number of reports associated with hour 0 (midnight up to but excluding 1 am), which would probably strike you as suspicious. Indeed, the reason is that there are some complaints that are dated but with no associated time, which was recorded in the data as exactly `00:00:00.000`.

# %%
query = '''
  SELECT COUNT(*)
    FROM data
    WHERE strftime ('%H:%M:%f', CreatedDate) = '00:00:00.000'
'''

pd.read_sql_query(query, disk_engine)
# Out:
#    COUNT(*)
# 0    532285

# %% [markdown]
# **Exercise 7** (2 points). What is the most common hour for noise complaints? Compute a tibble called `df_noisy_by_hour` whose variables are {`hour`, `count`} and whose observations are the number of noise complaints that occurred during a given `hour`. Consider a "noise complaint" to be any complaint string containing the word `noise`. Be sure to filter out any dates _without_ an associated time, i.e., a timestamp of `00:00:00.000`.

# %%
query = '''
    SELECT strftime ('%H', CreatedDate) AS hour, Count(*) as count
    FROM data
    WHERE strftime ('%H:%M:%f', CreatedDate) != '00:00:00.000'
    AND lower(ComplaintType) like lower('%noise%')
    GROUP BY hour
    ORDER BY count DESC
'''

df_noisy_by_hour = pd.read_sql_query(query, disk_engine)
display(df_noisy_by_hour)
# Out:
#    hour  count
# 0    23  19343
# 1    22  17155
# 2    00  15349
# 3    21  12659
# 4    01  11284
# 5    20   9790
# 6    19   7958
# 7    02   7170
# 8    18   6797
# 9    17   5126
# 10   09   5122
# 11   16   4957
# 12   11   4745
# 13   10   4672
# 14   15   4576
# 15   08   4553
# 16   14   4505
# 17   13   4364
# 18   12   4316
# 19   03   4241
# 20   07   3708
# 21   04   3083
# 22   06   2832
# 23   05   2084

# %%
# Test cell: `df_noisy_by_hour_test`

print ("Reading instructor's solution...")
if False:
    df_noisy_by_hour.to_csv('df_noisy_by_hour_soln.csv', index=False)
df_noisy_by_hour_soln = pd.read_csv ('df_noisy_by_hour_soln.csv')
display(df_noisy_by_hour_soln)

df_noisy_by_hour_norm = df_noisy_by_hour.copy()
df_noisy_by_hour_norm['hour'] = \
    df_noisy_by_hour_norm['hour'].apply(int)
assert tibbles_are_equivalent (df_noisy_by_hour_norm,
                               df_noisy_by_hour_soln)
print ("\n(Passed.)")
# Out:
# Reading instructor's solution...
#     hour  count
# 0      0  15349
# 1      1  11284
# 2      2   7170
# 3      3   4241
# 4      4   3083
# 5      5   2084
# 6      6   2832
# 7      7   3708
# 8      8   4553
# 9      9   5122
# 10    10   4672
# 11    11   4745
# 12    12   4316
# 13    13   4364
# 14    14   4505
# 15    15   4576
# 16    16   4957
# 17    17   5126
# 18    18   6797
# 19    19   7958
# 20    20   9790
# 21    21  12659
# 22    22  17155
# 23    23  19343
# (Passed.)

# %%
p = make_barchart(df_noisy_by_hour, 'hour', 'count',
                  {'title': 'Noise complaints by hour',
                   'plot_width': 800, 'plot_height': 320})
show(p)
# Out:
# /usr/local/lib/python3.5/dist-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b254ed95-c4d7-420f-829a-b32d016aa912"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b254ed95-c4d7-420f-829a-b32d016aa912");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b254ed95-c4d7-420f-829a-b32d016aa912");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b254ed95-c4d7-420f-829a-b32d016aa912' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0038021b-a07f-41f7-b9aa-8da8c93ef0a5":{"roots":{"references":[{"attributes":{},"id":"654da7cf-270f-4514-8bf4-1a18371c31e3","type":"LinearScale"},{"attributes":{"data_source":{"id":"692c9f30-8af3-4f72-8060-9b45044a3e4a","type":"ColumnDataSource"},"glyph":{"id":"258e447c-3488-44a4-8b92-569ba062f987","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6cd109d9-da89-4702-ac35-a9b3607ccfe2","type":"VBar"},"selection_glyph":null},"id":"f90eadab-4e6f-491c-a6b2-e86143203a0d","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"b73f0be3-c982-495c-85f7-614464fe1856","type":"CategoricalTickFormatter"},"plot":{"id":"7a7d1275-949e-4c1a-a043-c394c74ccdb9","subtype":"Figure","type":"Plot"},"ticker":{"id":"0c6f57b8-b24d-4d2d-b0d1-d654528eed43","type":"CategoricalTicker"}},"id":"eff23c28-e576-42f7-bb18-4b223e70b0d6","type":"CategoricalAxis"},{"attributes":{},"id":"9d46b161-a764-4cab-b5a6-93781a70ccf3","type":"ToolEvents"},{"attributes":{},"id":"0f5f7858-4015-4049-972a-4370c643c40e","type":"BasicTickFormatter"},{"attributes":{},"id":"0c6f57b8-b24d-4d2d-b0d1-d654528eed43","type":"CategoricalTicker"},{"attributes":{"overlay":{"id":"2054d25a-5baa-43f6-bd92-584914e6429f","type":"BoxAnnotation"},"plot":{"id":"7a7d1275-949e-4c1a-a043-c394c74ccdb9","subtype":"Figure","type":"Plot"}},"id":"d75b0f4a-824e-4e37-88d9-c1d4b8a22fe2","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"7a7d1275-949e-4c1a-a043-c394c74ccdb9","subtype":"Figure","type":"Plot"}},"id":"98365e21-8a75-4e7b-915b-fd4ab5e1ef89","type":"HelpTool"},{"attributes":{"plot":null,"text":"Noise complaints by hour"},"id":"d8d8083f-eade-4efc-9bda-65aa31fd9b12","type":"Title"},{"attributes":{},"id":"b73f0be3-c982-495c-85f7-614464fe1856","type":"CategoricalTickFormatter"},{"attributes":{"callback":null},"id":"5e996675-c3e8-41a9-ad60-1379fb0307b0","type":"DataRange1d"},{"attributes":{},"id":"248524d4-a168-454f-bc0b-0dfd51342aa1","type":"CategoricalScale"},{"attributes":{"dimension":1,"plot":{"id":"7a7d1275-949e-4c1a-a043-c394c74ccdb9","subtype":"Figure","type":"Plot"},"ticker":{"id":"a244beaa-f520-4cd8-a4dc-1e86045af3f2","type":"BasicTicker"}},"id":"04723a1d-1960-49af-8a14-b78e835d0ce0","type":"Grid"},{"attributes":{"plot":{"id":"7a7d1275-949e-4c1a-a043-c394c74ccdb9","subtype":"Figure","type":"Plot"},"ticker":{"id":"0c6f57b8-b24d-4d2d-b0d1-d654528eed43","type":"CategoricalTicker"}},"id":"2f1f0143-9d64-4599-9f5b-8629fc6e919f","type":"Grid"},{"attributes":{"plot":{"id":"7a7d1275-949e-4c1a-a043-c394c74ccdb9","subtype":"Figure","type":"Plot"}},"id":"80c2c2ba-7df2-4cc2-a08a-babedd31d558","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":[19343,17155,15349,12659,11284,9790,7958,7170,6797,5126,5122,4957,4745,4672,4576,4553,4505,4364,4316,4241,3708,3083,2832,2084],"x":["23","22","00","21","01","20","19","02","18","17","09","16","11","10","15","08","14","13","12","03","07","04","06","05"]}},"id":"692c9f30-8af3-4f72-8060-9b45044a3e4a","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.9},"x":{"field":"x"}},"id":"258e447c-3488-44a4-8b92-569ba062f987","type":"VBar"},{"attributes":{"plot":{"id":"7a7d1275-949e-4c1a-a043-c394c74ccdb9","subtype":"Figure","type":"Plot"}},"id":"aaf9528a-e757-4afe-b150-aaa257fd1683","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"0f5f7858-4015-4049-972a-4370c643c40e","type":"BasicTickFormatter"},"plot":{"id":"7a7d1275-949e-4c1a-a043-c394c74ccdb9","subtype":"Figure","type":"Plot"},"ticker":{"id":"a244beaa-f520-4cd8-a4dc-1e86045af3f2","type":"BasicTicker"}},"id":"6dc5d939-af73-4aa4-97a3-fae4c71607a7","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"96097bb6-1537-4672-870d-b890d3889566","type":"PanTool"},{"id":"aaf9528a-e757-4afe-b150-aaa257fd1683","type":"WheelZoomTool"},{"id":"d75b0f4a-824 ...

# %% [markdown]
# **Exercise 8** (ungraded). Create a line chart to show the fraction of complaints (y-axis) associated with each hour of the day (x-axis), with each complaint type shown as a differently colored line. Show just the top 5 complaints (`top_complaints[:5]`). Remember to exclude complaints with a zero-timestamp (i.e., `00:00:00.000`).
#
# > **Note.** This exercise is ungraded but we recommend spending some time giving it a try! Feel free to discuss your approaches to this problem on the discussion forums (but do try to do it yourself first). One library you may find useful to try out is holoviews (http://holoviews.org/index.html)

# %%
import holoviews as hv
hv.extension('bokeh')
from holoviews import Bars

#
# YOUR CODE HERE
#

# %% [markdown]
# ### Learn more
#
# - Find more open data sets on [Data.gov](https://data.gov) and [NYC Open Data](https://nycopendata.socrata.com)
# - Learn how to setup [MySql with Pandas and Plotly](http://moderndata.plot.ly/graph-data-from-mysql-database-in-python/)
# - Big data workflows with [HDF5 and Pandas](http://stackoverflow.com/questions/14262433/large-data-work-flows-using-pandas)
